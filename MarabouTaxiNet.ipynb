# %% [markdown]
# <a href="https://colab.research.google.com/github/safednn-nasa/Prophecy/blob/master/MarabouTaxiNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/safednn-nasa/Prophecy
# Out:
# Cloning into 'Prophecy'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 164 (delta 27), reused 3 (delta 1), pack-reused 108
# Receiving objects: 100% (164/164), 1.93 MiB | 14.22 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# The following is the property file 
# !cat Prophecy/propertyTaxiNet.txt
# Out:
# x0 >= -0.03
# x0 <= 0.03
# x1 >= -0.03
# x1 <= 0.03
# x2 >= -0.03
# x2 <= 0.03
# x3 >= -0.03
# x3 <= 0.03
# x4 >= -0.03
# x4 <= 0.03
# x5 >= -0.03
# x5 <= 0.03
# x6 >= -0.03
# x6 <= 0.03
# x7 >= -0.03
# x7 <= 0.03
# x8 >= -0.03
# x8 <= 0.03
# x9 >= -0.03
# x9 <= 0.03
# x10 >= -0.03
# x10 <= 0.03
# x11 >= -0.03
# x11 <= 0.03
# x12 >= -0.03
# x12 <= 0.03
# x13 >= -0.03
# x13 <= 0.03
# x14 >= -0.03
# x14 <= 0.03
# x15 >= -0.03
# x15 <= 0.03
# x16 >= -0.03
# x16 <= 0.03
# x17 >= -0.03
# x17 <= 0.03
# x18 >= -0.03
# x18 <= 0.03
# x19 >= -0.03
# x19 <= 0.03
# x20 >= -0.03
# x20 <= 0.03
# x21 >= -0.03
# x21 <= 0.03
# x22 >= -0.03
# x22 <= 0.03
# x23 >= -0.03
# x23 <= 0.03
# x24 >= -0.03
# x24 <= 0.03
# x25 >= -0.03
# x25 <= 0.03
# x26 >= -0.03
# x26 <= 0.03
# x27 >= -0.03
# x27 <= 0.03
# x28 >= -0.03
# x28 <= 0.03
# x29 >= -0.03
# x29 <= 0.03
# x30 >= -0.03
# x30 <= 0.03
# x31 >= -0.03
# x31 <= 0.03
# x32 >= -0.03
# x32 <= 0.03
# x33 >= -0.03
# x33 <= 0.03
# x34 >= -0.03
# x34 <= 0.03
# x35 >= -0.03
# x35 <= 0.03
# x36 >= -0.03
# x36 <= 0.03
# x37 >= -0.03
# x37 <= 0.03
# x38 >= -0.03
# x38 <= 0.03
# x39 >= -0.03
# x39 <= 0.03
# x40 >= -0.03
# x40 <= 0.03
# x41 >= -0.03
# x41 <= 0.03
# x42 >= -0.03
# x42 <= 0.03
# x43 >= -0.03
# x43 <= 0.03
# x44 >= -0.03
# x44 <= 0.03
# x45 >= -0.03
# x45 <= 0.03
# x46 >= -0.03
# x46 <= 0.03
# x47 >= -0.03
# x47 <= 0.03
# x48 >= -0.03
# x48 <= 0.03
# x49 >= -0.03
# x49 <= 0.03
# x50 >= -0.03
# x50 <= 0.03
# x51 >= -0.03
# x51 <= 0.03
# x52 >= -0.03
# x52 <= 0.03
# x53 >= -0.03
# x53 <= 0.03
# x54 >= -0.03
# x54 <= 0.03
# x55 >= -0.03
# x55 <= 0.03
# x56 >= -0.03
# x56 <= 0.03
# x57 >= -0.03
# x57 <= 0.03
# x58 >= -0.03
# x58 <= 0.03
# x59 >= -0.03
# x59 <= 0.03
# x60 >= -0.03
# x60 <= 0.03
# x61 >= -0.03
# x61 <= 0.03
# x62 >= -0.03
# x62 <= 0.03
# x63 >= -0.03
# x63 <= 0.03
# x64 >= -0.03
# x64 <= 0.03
# x65 >= -0.03
# x65 <= 0.03
# x66 >= -0.03
# x66 <= 0.03
# x67 >= -0.03
# x67 <= 0.03
# x68 >= -0.03
# x68 <= 0.03
# x69 >= -0.03
# x69 <= 0.03
# x70 >= -0.03
# x70 <= 0.03
# x71 >= -0.03
# x71 <= 0.03
# x72 >= -0.03
# x72 <= 0.03
# x73 >= -0.03
# x73 <= 0.03
# x74 >= -0.03
# x74 <= 0.03
# x75 >= -0.03
# x75 <= 0.03
# x76 >= -0.03
# x76 <= 0.03
# x77 >= -0.03
# x77 <= 0.03
# x78 >= -0.03
# x78 <= 0.03
# x79 >= -0.03
# x79 <= 0.03
# x80 >= -0.03
# x80 <= 0.03
# x81 >= -0.03
# x81 <= 0.03
# x82 >= -0.03
# x82 <= 0.03
# x83 >= -0.03
# x83 <= 0.03
# x84 >= -0.03
# x84 <= 0.03
# x85 >= -0.03
# x85 <= 0.03
# x86 >= -0.03
# x86 <= 0.03
# x87 >= -0.03
# x87 <= 0.03
# x88 >= -0.03
# x88 <= 0.03
# x89 >= -0.03
# x89 <= 0.03
# x90 >= -0.03
# x90 <= 0.03
# x91 >= -0.03
# x91 <= 0.03
# x92 >= -0.03
# x92 <= 0.03
# x93 >= -0.03
# x93 <= 0.03
# x94 >= -0.03
# x94 <= 0.03
# x95 >= -0.03
# x95 <= 0.03
# x96 >= -0.03
# x96 <= 0.03
# x97 >= -0.03
# x97 <= 0.03
# x98 >= -0.03
# x98 <= 0.03
# x99 >= -0.03
# x99 <= 0.03
# x100 >= -0.03
# x100 <= 0.03
# x101 >= -0.03
# x101 <= 0.03
# x102 >= -0.03
# x102 <= 0.03
# x103 >= -0.03
# x103 <= 0.03
# x104 >= -0.03
# x104 <= 0.03
# x105 >= -0.03
# x105 <= 0.03
# x106 >= -0.03
# x106 <= 0.03
# x107 >= -0.03
# x107 <= 0.03
# x108 >= -0.03
# x108 <= 0.03
# x109 >= -0.03
# x109 <= 0.03
# x110 >= -0.03
# x110 <= 0.03
# x111 >= -0.03
# x111 <= 0.03
# x112 >= -0.03
# x112 <= 0.03
# x113 >= -0.03
# x113 <= 0.03
# x114 >= -0.03
# x114 <= 0.03
# x115 >= -0.03
# x115 <= 0.03
# x116 >= -0.03
# x116 <= 0.03
# x117 >= -0.03
# x117 <= 0.03
# x118 >= -0.03
# x118 <= 0.03
# x119 >= 0.7190196078431372
# x119 <= 0.7790196078431373
# x120 >= 0.97
# x120 <= 1.03
# x121 >= 0.97
# x121 <= 1.03
# x122 >= 0.97
# x122 <= 1.03
# x123 >= 0.7190196078431372
# x123 <= 0.7790196078431373
# x124 >= -0.03
# x124 <= 0.03
# x125 >= -0.03
# x125 <= 0.03
# x126 >= -0.03
# x126 <= 0.03
# x127 >= -0.03
# x127 <= 0.03
# y0 >=0

# %%
# get Marabou
# !git clone https://github.com/anwu1219/MarabouExample
# Out:
# fatal: destination path 'MarabouExample' already exists and is not an empty directory.

# %%
# run Marabou
# !MarabouExample/Marabou-nosbt Prophecy/KJ_TaxiNet.nnet Prophecy/propertyTaxiNet.txt --summary-file=result.txt --verbosity=0
# Out:
# Network: Prophecy/KJ_TaxiNet.nnet
# Number of layers: 5. Input layer size: 128. Output layer size: 2. Number of ReLUs: 32
# Total number of variables: 194
# Property: Prophecy/propertyTaxiNet.txt
# Caught a InputParserError error. Code: 1, Errno: 0, Message: y0 >=0.
